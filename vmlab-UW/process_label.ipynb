# %%
from sklearn.preprocessing import OneHotEncoder
import sys
import tensorflow as tf
import os
import SimpleITK as sitk
import yaml
import numpy as np

# %%
with open("444428.yml") as f:
    yamlobj = yaml.load(f)
    model = tf.keras.models.model_from_yaml(yaml.dump(yamlobj))
    
# get patchsize
print("input_shape =", model.input_shape)
print("output_shape =", model.output_shape)
ps = np.array(model.output_shape[1:4])[::-1]
ips = np.array(model.input_shape[1:4])[::-1]
ds = ((ips - ps) / 2).astype(np.int)

print("ps:{}, ips:{}, ds:{}".format(ps, ips, ds))
# Out:
# input_shape = (None, 116, 132, 132, 1)
# output_shape = (None, 28, 44, 44, 2)
# ps:[44 44 28], ips:[132 132 116], ds:[44 44 44]

# %%
def Padding(image, patchsize, imagepatchsize, mirroring = False):
    padfilter = sitk.MirrorPadImageFilter() if mirroring else sitk.ConstantPadImageFilter()
    padfilter.SetPadLowerBound(patchsize.tolist())
    padfilter.SetPadUpperBound(imagepatchsize.tolist())
    padded_image = padfilter.Execute(image)
    return padded_image

def createParentPath(filepath):
    if not os.path.exists(filepath):
        os.makedirs(filepath)
        print("path created")

# %% [markdown]
# ## creat mask

# %%
for i in os.listdir(r"D:\comp30\RawData\Training\label"):
    filepath=os.path.join(r"D:\comp30\RawData\Training\label",i)
    filepath=os.path.join(filepath,"label.mha")
    print(filepath)
    savepath=os.path.join(r"D:\comp30\RawData\Training\label",i)
    
    image = sitk.ReadImage(filepath)
    image_array=sitk.GetArrayFromImage(image)
    print("shpe",image_array.shape)
    print("mac",np.max(image_array))
    image_array[image_array>0]=1
    print("shpe",image_array.shape)
    print("mac",np.max(image_array))
    outimage = sitk.GetImageFromArray(image_array)
    outimage.SetOrigin(image.GetOrigin())
    outimage.SetSpacing(image.GetSpacing())
    outimage.SetDirection(image.GetDirection())
    sitk.WriteImage(outimage, savepath+"/mask.mha", True)
# Out:
# D:\comp30\RawData\Training\label\label0001.nii\label.mha
# shpe (147, 512, 512)
# mac 13
# shpe (147, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0002.nii\label.mha
# shpe (139, 512, 512)
# mac 13
# shpe (139, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0003.nii\label.mha
# shpe (198, 512, 512)
# mac 13
# shpe (198, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0004.nii\label.mha
# shpe (140, 512, 512)
# mac 13
# shpe (140, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0005.nii\label.mha
# shpe (117, 512, 512)
# mac 13
# shpe (117, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0006.nii\label.mha
# shpe (131, 512, 512)
# mac 13
# shpe (131, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0007.nii\label.mha
# shpe (163, 512, 512)
# mac 13
# shpe (163, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0008.nii\label.mha
# shpe (148, 512, 512)
# mac 13
# shpe (148, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0009.nii\label.mha
# shpe (149, 512, 512)
# mac 13
# shpe (149, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0010.nii\label.mha
# shpe (148, 512, 512)
# mac 13
# shpe (148, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0021.nii\label.mha
# shpe (143, 512, 512)
# mac 13
# shpe (143, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0022.nii\label.mha
# shpe (89, 512, 512)
# mac 13
# shpe (89, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0023.nii\label.mha
# shpe (96, 512, 512)
# mac 13
# shpe (96, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0024.nii\label.mha
# shpe (124, 512, 512)
# mac 13
# shpe (124, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0025.nii\label.mha
# shpe (85, 512, 512)
# mac 13
# shpe (85, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0026.nii\label.mha
# shpe (131, 512, 512)
# mac 13
# shpe (131, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0027.nii\label.mha
# shpe (88, 512, 512)
# mac 13
# shpe (88, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0028.nii\label.mha
# shpe (89, 512, 512)
# mac 13
# shpe (89, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0029.nii\label.mha
# shpe (100, 512, 512)
# mac 13
# shpe (100, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0030.nii\label.mha
# shpe (153, 512, 512)
# mac 13
# shpe (153, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0031.nii\label.mha
# shpe (93, 512, 512)
# mac 13
# shpe (93, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0032.nii\label.mha
# shpe (144, 512, 512)
# mac 13
# shpe (144, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0033.nii\label.mha
# shpe (104, 512, 512)
# mac 13
# shpe (104, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0034.nii\label.mha
# shpe (98, 512, 512)
# mac 13
# shpe (98, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0035.nii\label.mha
# shpe (94, 512, 512)
# mac 13
# shpe (94, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0036.nii\label.mha
# shpe (184, 512, 512)
# mac 13
# shpe (184, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0037.nii\label.mha
# shpe (99, 512, 512)
# mac 13
# shpe (99, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0038.nii\label.mha
# shpe (100, 512, 512)
# mac 13
# shpe (100, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0039.nii\label.mha
# shpe (90, 512, 512)
# mac 13
# shpe (90, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0040.nii\label.mha
# shpe (195, 512, 512)
# mac 13
# shpe (195, 512, 512)
# mac 1

# %% [markdown]
# ### 8 origan  mask
#
# liver            6   5
#
# spleen           1   1
#
# left_kidney      3   3
#
# right_kidney     2   2
#
# pancreas         11  8
#
# GB(gallbladder)  4   4
#
# aorta            8   6
#
# IVC              9   7

# %%
for i in os.listdir(r"D:\comp30\RawData\Training\label"):
    filepath=os.path.join(r"D:\comp30\RawData\Training\label",i)
    filepath=os.path.join(filepath,"label.mha")
    print(filepath)
    savepath=os.path.join(r"D:\comp30\RawData\Training\label",i)
    
    image = sitk.ReadImage(filepath)
    image_array=sitk.GetArrayFromImage(image)
    print("shpe",image_array.shape)
    print("mac",np.max(image_array))
    
    image_array[image_array==1]=1
    image_array[image_array==2]=1
    image_array[image_array==3]=1
    image_array[image_array==4]=1
    image_array[image_array==5]=0
    image_array[image_array==6]=1
    image_array[image_array==7]=0
    image_array[image_array==8]=1
    image_array[image_array==9]=1
    image_array[image_array==10]=0
    image_array[image_array==11]=1
    image_array[image_array==12]=0
    image_array[image_array==13]=0
    
    print("shpe",image_array.shape)
    print("mac",np.max(image_array))
    outimage = sitk.GetImageFromArray(image_array)
    outimage.SetOrigin(image.GetOrigin())
    outimage.SetSpacing(image.GetSpacing())
    outimage.SetDirection(image.GetDirection())
    sitk.WriteImage(outimage, savepath+"/mask_8.mha", True)
# Out:
# D:\comp30\RawData\Training\label\label0001.nii\label.mha
# shpe (147, 512, 512)
# mac 13
# shpe (147, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0002.nii\label.mha
# shpe (139, 512, 512)
# mac 13
# shpe (139, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0003.nii\label.mha
# shpe (198, 512, 512)
# mac 13
# shpe (198, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0004.nii\label.mha
# shpe (140, 512, 512)
# mac 13
# shpe (140, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0005.nii\label.mha
# shpe (117, 512, 512)
# mac 13
# shpe (117, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0006.nii\label.mha
# shpe (131, 512, 512)
# mac 13
# shpe (131, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0007.nii\label.mha
# shpe (163, 512, 512)
# mac 13
# shpe (163, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0008.nii\label.mha
# shpe (148, 512, 512)
# mac 13
# shpe (148, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0009.nii\label.mha
# shpe (149, 512, 512)
# mac 13
# shpe (149, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0010.nii\label.mha
# shpe (148, 512, 512)
# mac 13
# shpe (148, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0021.nii\label.mha
# shpe (143, 512, 512)
# mac 13
# shpe (143, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0022.nii\label.mha
# shpe (89, 512, 512)
# mac 13
# shpe (89, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0023.nii\label.mha
# shpe (96, 512, 512)
# mac 13
# shpe (96, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0024.nii\label.mha
# shpe (124, 512, 512)
# mac 13
# shpe (124, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0025.nii\label.mha
# shpe (85, 512, 512)
# mac 13
# shpe (85, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0026.nii\label.mha
# shpe (131, 512, 512)
# mac 13
# shpe (131, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0027.nii\label.mha
# shpe (88, 512, 512)
# mac 13
# shpe (88, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0028.nii\label.mha
# shpe (89, 512, 512)
# mac 13
# shpe (89, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0029.nii\label.mha
# shpe (100, 512, 512)
# mac 13
# shpe (100, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0030.nii\label.mha
# shpe (153, 512, 512)
# mac 13
# shpe (153, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0031.nii\label.mha
# shpe (93, 512, 512)
# mac 13
# shpe (93, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0032.nii\label.mha
# shpe (144, 512, 512)
# mac 13
# shpe (144, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0033.nii\label.mha
# shpe (104, 512, 512)
# mac 13
# shpe (104, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0034.nii\label.mha
# shpe (98, 512, 512)
# mac 13
# shpe (98, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0035.nii\label.mha
# shpe (94, 512, 512)
# mac 13
# shpe (94, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0036.nii\label.mha
# shpe (184, 512, 512)
# mac 13
# shpe (184, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0037.nii\label.mha
# shpe (99, 512, 512)
# mac 13
# shpe (99, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0038.nii\label.mha
# shpe (100, 512, 512)
# mac 13
# shpe (100, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0039.nii\label.mha
# shpe (90, 512, 512)
# mac 13
# shpe (90, 512, 512)
# mac 1
# D:\comp30\RawData\Training\label\label0040.nii\label.mha
# shpe (195, 512, 512)
# mac 13
# shpe (195, 512, 512)
# mac 1

# %% [markdown]
# ### 8 origan label
#
# liver            6   5
#
# spleen           1   1
#
# left_kidney      3   3
#
# right_kidney     2   2
#
# pancreas         11  8
#
# GB(gallbladder)  4   4
#
# aorta            8   6
#
# IVC              9   7

# %%
for i in os.listdir(r"D:\comp30\RawData\Training\label"):
    filepath=os.path.join(r"D:\comp30\RawData\Training\label",i)
    filepath=os.path.join(filepath,"label.mha")
    print(filepath)
    savepath=os.path.join(r"D:\comp30\RawData\Training\label",i)
    
    image = sitk.ReadImage(filepath)
    image_array=sitk.GetArrayFromImage(image)
    print("shpe",image_array.shape)
    print("mac",np.max(image_array))
    
    #image_array[image_array==1]=1
    #image_array[image_array==2]=1
    #image_array[image_array==3]=1
    #image_array[image_array==4]=1
    image_array[image_array==5]=0
    image_array[image_array==6]=5
    image_array[image_array==7]=0
    image_array[image_array==8]=6
    image_array[image_array==9]=7
    image_array[image_array==10]=0
    image_array[image_array==11]=8
    image_array[image_array==12]=0
    image_array[image_array==13]=0
    
    print("shpe",image_array.shape)
    print("mac",np.max(image_array))
    outimage = sitk.GetImageFromArray(image_array)
    outimage.SetOrigin(image.GetOrigin())
    outimage.SetSpacing(image.GetSpacing())
    outimage.SetDirection(image.GetDirection())
    sitk.WriteImage(outimage, savepath+"/label_8.mha", True)
# Out:
# D:\comp30\RawData\Training\label\label0001.nii\label.mha
# shpe (147, 512, 512)
# mac 13
# shpe (147, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0002.nii\label.mha
# shpe (139, 512, 512)
# mac 13
# shpe (139, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0003.nii\label.mha
# shpe (198, 512, 512)
# mac 13
# shpe (198, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0004.nii\label.mha
# shpe (140, 512, 512)
# mac 13
# shpe (140, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0005.nii\label.mha
# shpe (117, 512, 512)
# mac 13
# shpe (117, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0006.nii\label.mha
# shpe (131, 512, 512)
# mac 13
# shpe (131, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0007.nii\label.mha
# shpe (163, 512, 512)
# mac 13
# shpe (163, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0008.nii\label.mha
# shpe (148, 512, 512)
# mac 13
# shpe (148, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0009.nii\label.mha
# shpe (149, 512, 512)
# mac 13
# shpe (149, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0010.nii\label.mha
# shpe (148, 512, 512)
# mac 13
# shpe (148, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0021.nii\label.mha
# shpe (143, 512, 512)
# mac 13
# shpe (143, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0022.nii\label.mha
# shpe (89, 512, 512)
# mac 13
# shpe (89, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0023.nii\label.mha
# shpe (96, 512, 512)
# mac 13
# shpe (96, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0024.nii\label.mha
# shpe (124, 512, 512)
# mac 13
# shpe (124, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0025.nii\label.mha
# shpe (85, 512, 512)
# mac 13
# shpe (85, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0026.nii\label.mha
# shpe (131, 512, 512)
# mac 13
# shpe (131, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0027.nii\label.mha
# shpe (88, 512, 512)
# mac 13
# shpe (88, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0028.nii\label.mha
# shpe (89, 512, 512)
# mac 13
# shpe (89, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0029.nii\label.mha
# shpe (100, 512, 512)
# mac 13
# shpe (100, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0030.nii\label.mha
# shpe (153, 512, 512)
# mac 13
# shpe (153, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0031.nii\label.mha
# shpe (93, 512, 512)
# mac 13
# shpe (93, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0032.nii\label.mha
# shpe (144, 512, 512)
# mac 13
# shpe (144, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0033.nii\label.mha
# shpe (104, 512, 512)
# mac 13
# shpe (104, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0034.nii\label.mha
# shpe (98, 512, 512)
# mac 13
# shpe (98, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0035.nii\label.mha
# shpe (94, 512, 512)
# mac 13
# shpe (94, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0036.nii\label.mha
# shpe (184, 512, 512)
# mac 13
# shpe (184, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0037.nii\label.mha
# shpe (99, 512, 512)
# mac 13
# shpe (99, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0038.nii\label.mha
# shpe (100, 512, 512)
# mac 13
# shpe (100, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0039.nii\label.mha
# shpe (90, 512, 512)
# mac 13
# shpe (90, 512, 512)
# mac 8
# D:\comp30\RawData\Training\label\label0040.nii\label.mha
# shpe (195, 512, 512)
# mac 13
# shpe (195, 512, 512)
# mac 8
